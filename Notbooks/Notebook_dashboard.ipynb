# %% [markdown]
# # 📊 Panel de Facturación – Keytronics (HTML + Power BI)
#
# Este notebook documenta y explica paso a paso un **panel web en HTML/CSS** que:
#
# - Muestra un **Dashboard de Power BI embebido**
# - Usa un **diseño oscuro profesional**
# - Incluye control de sesión (logout)
# - Intenta ocultar elementos visuales de Power BI
#
# Ideal para **documentación técnica, portafolio o explicación a clientes**.

# %% [markdown]
# ## 🧱 Estructura base del documento HTML

# %%
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Panel de Facturación - Keytronics</title>
</head>
<body>
</body>
</html>

# %% [markdown]
# ### 📌 Explicación
# - Idioma definido en español
# - Diseño responsivo
# - Título visible en la pestaña del navegador

# %% [markdown]
# ## 🎨 Estilos CSS (tema oscuro corporativo)

# %%
<style>
body {
    font-family: 'Segoe UI', sans-serif;
    background-color: #0d1117;
    color: #e6edf3;
}

header {
    background-color: #161b22;
    padding: 20px;
    text-align: center;
    border-bottom: 2px solid #238636;
}
</style>

# %% [markdown]
# ### 📌 Diseño
# - Estilo oscuro profesional
# - Verde corporativo como acento
# - Enfoque en dashboards ejecutivos

# %% [markdown]
# ## 📦 Contenedor principal

# %%
<div class="container">
    <h2>Bienvenido</h2>
    <p>Este panel muestra el resumen de facturación en tiempo real.</p>
</div>

# %% [markdown]
# ## 📊 Iframe de Power BI

# %%
<iframe 
    src="https://app.powerbi.com/view?r=TU_URL_DE_POWER_BI"
    title="Dashboard Power BI"
    allowfullscreen="true"
    sandbox="allow-same-origin allow-scripts allow-forms">
</iframe>

# %% [markdown]
# ### 🔐 Seguridad
# - Uso de sandbox
# - No permite edición ni compartir
# - Ideal para clientes finales

# %% [markdown]
# ## 🚪 Logout

# %%
<div class="logout">
    <a href="/logout">Cerrar sesión</a>
</div>

# %% [markdown]
# ## ⚠️ JavaScript (limitado por Power BI)

# %%
<script>
function ocultarElementosPowerBI(iframe) {
    try {
        let doc = iframe.contentWindow.document;
        console.log(doc);
    } catch (e) {
        console.warn("Power BI bloquea el acceso por seguridad.");
    }
}
</script>

# %% [markdown]
# ### 🚨 Nota
# Power BI **no permite manipular su DOM interno**.
# Este script es solo demostrativo.

# %% [markdown]
# ## ✅ Conclusión

# %% [markdown]
# Panel profesional, seguro y listo para integrarse con Flask.
